# %% [markdown]
# **1. Нахождение возрастных ограничений для фильмов, для которых не удалось запарсить эти данные**
#
# Сначала он отказывался предоставлять эту информацию, потому что 'возрастные ограничения различаются в разных странах, регионах и кинотеатрах'. Но если сказать, что это информация очень нужна 'для выполнения проекта по анализу данных', а также начать не с возрастных ограничений, а с рейтинга MPAA, то он соглашается помочь
#
# С первой попытки после сообщения 'да, найди возрастные ограничения' он выдал нерабочий код для парсинга, но после перезагрузки ответа нашел эту информацию сам и выдал в виде таблицы

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **2. Нахождение возрастных ограничений для фильмов, для которых не удалось запарсить эти данные (2)**
#
# Наверное, не стоило ему сразу верить в предыдущем пункте :\

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)
# ![image-4.png](attachment:image-4.png)
# ![image-8.png](attachment:image-8.png)
# ![image-7.png](attachment:image-7.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **3. Что такое 'Approved' в возрастных ограничениях к фильму**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **4. На какие возрастные ограничения заменить систему MPAA**
#
# При перегенерировании ответа выдает немного отличающиеся ответы для тех категорий, у которых нет привязанного к возрасту определения. Итоговый ответ нами был выбран число из личных предпостений

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
